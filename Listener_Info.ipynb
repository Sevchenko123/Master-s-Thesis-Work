# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas import Series,DataFrame
from numpy.random import randn
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
Listener_Info1 = pd.read_csv('Listener_Info_Active_Har.csv') # Listeners who engaged with active harassers
Listener_Info2 = pd.read_csv('Listener_Info_Freq_Har.csv') # Listeners who engaged with frequent harassers

# %%
sns.factorplot('gender',data=Listener_Info1,kind='count',palette='Set1')

# %%
sns.factorplot('gender',data=Listener_Info2,kind='count',palette='Set2')

# %%
c1 = Listener_Info1['Country'].value_counts()

# %%
c1 = c1[0:9,]

# %%
c1.plot(kind='bar',figsize=(8,8),color='indianred')

# %%
c2 = Listener_Info2['Country'].value_counts()
c2 = c2[0:9,]

# %%
c2.plot(kind='bar',figsize=(8,8),color='plum')

# %%
plt.figure(figsize=(5,5))
sns.factorplot('State',data=Listener_Info1,kind='count',palette='Blues_r',aspect=3,size=5)
plt.savefig("Harassment_State.pdf",transparent=True)
