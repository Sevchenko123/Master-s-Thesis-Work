# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas import Series,DataFrame
from numpy.random import randn
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
Listener_Info1 = pd.read_csv('Listener_Info_Active.csv') # Listeners who engaged with active harassers
Listener_Info2 = pd.read_csv('Listener_Info_Freq.csv') # Listeners who engaged with frequent harassers

# %%
sns.factorplot('gender',data=Listener_Info1,kind='count',palette='Set1')

# %% [markdown]
# The above barplot shows the gender of the listeners connecting to active harassers.

# %%
Listener_Info1['gender'].value_counts()
# Out:
# F    15169
# M     6023
# O      483
# Name: gender, dtype: int64

# %%
sns.factorplot('gender',data=Listener_Info2,kind='count',palette='Set1')

# %% [markdown]
# The above barplot shows the gender of the listeners connecting to frequent harassers.

# %%
Listener_Info2['gender'].value_counts()
# Out:
# F    19558
# M     5528
# O      513
# Name: gender, dtype: int64

# %%
c1 = Listener_Info1['Country'].value_counts()

# %%
c1 = c1[0:9,]

# %%
# Listeners connecting to active harassers from top 9 countries.
c1.plot(kind='bar',figsize=(8,8),color='indianred')

# %% [markdown]
# The top 5 countries the listeners are from, connecting to active harassers are USA, UK, India, Canada and Australia.

# %%
# Listeners connecting to Frequent harassers from top 9 countries.
c2.plot(kind='bar',figsize=(8,8),color='plum')

# %% [markdown]
# The top 5 countries the listeners are from, connecting to frequent harassers are USA, UK, India, Canada and Australia.

# %%
# Listeners State Info, connecting to Active Harassers within US.
plt.figure(figsize=(5,5)) 
sns.factorplot('State',data=Listener_Info1,kind='count',palette='Blues_r',aspect=3,size=5)
plt.savefig("Harassment_State.pdf",transparent=True)

# %% [markdown]
# Within USA the prominent states the listeners are from, connecting to active harassers are California, New York, Texas, Florida.

# %%
# Listeners State Info, connecting to Frequent Harassers within US.
plt.figure(figsize=(5,5))
sns.factorplot('State',data=L2,kind='count',palette='Blues_r',aspect=3,size=5)
plt.savefig("FreqHarassment_State.pdf",transparent=True)

# %% [markdown]
# Within USA the prominent states the listeners are from, connecting to frequent harassers are California, New York, Texas, Florida.

# %%
Listener_Info3 = pd.read_csv('Listener_Info_Normal.csv')

# %%
sns.factorplot('gender',data=Listener_Info3,kind='count',palette='Set2')

# %% [markdown]
# The above barplot shows the gender of the listeners connecting to active normal members.

# %%
Listener_Info3['gender'].value_counts()
# Out:
# F    35446
# M    12834
# O     1209
# Name: gender, dtype: int64

# %%
c3 = Listener_Info3['Country'].value_counts()
c3 = c3[0:10,]

# %%
# Listeners connecting to active normal members from top 10 countries.
c3.plot(kind='bar',figsize=(8,8),color='darkblue')

# %% [markdown]
# The top 5 countries the listeners are from, connecting to active normal members are USA, UK, India, Canada and Australia.

# %%
# Listeners State Info, connecting to Active normal members within US.
plt.figure(figsize=(5,5)) 
sns.factorplot('State',data=Listener_Info3,kind='count',palette='Reds_r',aspect=3,size=5)
plt.savefig("Harassment_State.pdf",transparent=True)

# %% [markdown]
# Within USA the prominent states the listeners are from, connecting to normal active members are California, New York, Texas, Florida.
